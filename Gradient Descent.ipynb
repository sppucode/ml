# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Gradient Descent to find local minima of y = (x + 3)^2

# Function and its derivative
def f(x):
    return (x + 3)**2

def df(x):
    return 2 * (x + 3)

# Initialize parameters
x = 2              # starting point
learning_rate = 0.1
iteration = 30        # number of iterations
x_points = [x]
tol=0.000006

# Gradient Descent loop
for i in range(iteration):
    x_new = x - learning_rate * df(x)   # update x
    print(f"Iteration {i+1}: x = {x:.4f}, f(x) = {f(x):.4f}")
    x_points.append(x_new)
    if abs(x_new - x) < tol:  # convergence check
        break
    x=x_new

print("\nLocal minima occurs at x =", round(x, 4))
# Out:
# Iteration 1: x = 2.0000, f(x) = 25.0000
# Iteration 2: x = 1.0000, f(x) = 16.0000
# Iteration 3: x = 0.2000, f(x) = 10.2400
# Iteration 4: x = -0.4400, f(x) = 6.5536
# Iteration 5: x = -0.9520, f(x) = 4.1943
# Iteration 6: x = -1.3616, f(x) = 2.6844
# Iteration 7: x = -1.6893, f(x) = 1.7180
# Iteration 8: x = -1.9514, f(x) = 1.0995
# Iteration 9: x = -2.1611, f(x) = 0.7037
# Iteration 10: x = -2.3289, f(x) = 0.4504
# Iteration 11: x = -2.4631, f(x) = 0.2882
# Iteration 12: x = -2.5705, f(x) = 0.1845
# Iteration 13: x = -2.6564, f(x) = 0.1181
# Iteration 14: x = -2.7251, f(x) = 0.0756
# Iteration 15: x = -2.7801, f(x) = 0.0484
# Iteration 16: x = -2.8241, f(x) = 0.0309
# Iteration 17: x = -2.8593, f(x) = 0.0198
# Iteration 18: x = -2.8874, f(x) = 0.0127
# Iteration 19: x = -2.9099, f(x) = 0.0081
# Iteration 20: x = -2.9279, f(x) = 0.0052
# Iteration 21: x = -2.9424, f(x) = 0.0033
# Iteration 22: x = -2.9539, f(x) = 0.0021
# Iteration 23: x = -2.9631, f(x) = 0.0014
# Iteration 24: x = -2.9705, f(x) = 0.0009
# Iteration 25: x = -2.9764, f(x) = 0.0006
# Iteration 26: x = -2.9811, f(x) = 0.0004
# Iteration 27: x = -2.9849, f(x) = 0.0002
# Iteration 28: x = -2.9879, f(x) = 0.0001
# Iteration 29: x = -2.9903, f(x) = 0.0001
# Iteration 30: x = -2.9923, f(x) = 0.0001
#
# Local minima occurs at x = -2.9938

# %%
# Visualization
x_vals = np.linspace(-6, 2, 100)
y_vals = f(x_vals)

# %%
plt.plot(x_vals, y_vals, label='$y = (x + 3)^2$', color='blue')
plt.scatter(x_points, f(np.array(x_points)), color='red')  # steps
plt.title("Gradient Descent on $y = (x + 3)^2$")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()
